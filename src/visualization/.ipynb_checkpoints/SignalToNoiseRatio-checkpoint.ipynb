# %% [markdown]
# # <font color="purple">SNR Result</font>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
column = [100,50,45,40,33]
# add results
resnet_adv = [0.718848, 0.666492, 0.633682, 0.557068, 0.416928]
resnet = [0.724782, 0.676265, 0.641536, 0.558115, 0.41274]

# %%
parseval = [0.735777,0.688133,0.658988,0.57644,0.429319]
parseval_adv = [0.72897, 0.683944, 0.650087, 0.568412, 0.4363]

# %%
legend = ["ResNet", "ResNet_adv","Parseval", "Parseval_adv"]
plt.plot(column, resnet, 'o-')
plt.plot(column, resnet_adv, 'o-')
plt.plot(column, parseval, 'o-')
plt.plot(column, parseval_adv, 'o-')

plt.ylabel('accuracy')
plt.xlabel('SNR')
plt.legend(legend, loc='lower right')
plt.show()
