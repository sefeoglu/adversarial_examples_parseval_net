# %% [markdown]
# Model Selection
# Evaluation of GridSearch CV Results

# %%
import pandas as pd
import numpy as np

# %%
data1  = pd.read_csv("grid1.csv", sep=";")
data2  = pd.read_csv("grid2.csv", sep=";")
data3  = pd.read_csv("grid3.csv", sep=";")
data4  = pd.read_csv("grid4.csv", sep=";")
data5  = pd.read_csv("grid5.csv", sep=";")

# %%
data_combine = pd.concat([data1, data2, data3, data4, data5])

# %%
data_combine
# Out:
#     Unnamed: 0  momentum  ...  epoch_stopped3  reg_penalty
# 0            0       0.7  ...            50.0       0.0100
# 1            1       0.6  ...            50.0       0.0100
# 2            2       0.7  ...           100.0       0.0100
# 3            3       0.6  ...           100.0       0.0100
# 4            4       0.7  ...           150.0       0.0100
# ..         ...       ...  ...             ...          ...
# 6            6       0.7  ...            50.0       0.0001
# 7            7       0.6  ...            50.0       0.0001
# 8            8       0.7  ...           100.0       0.0001
# 9            9       0.6  ...           100.0       0.0001
# 10          10       0.7  ...           150.0       0.0001
#
# [105 rows x 14 columns]

# %%
data_combine["loss_mean"] = (data_combine["loss1"]+data_combine["loss2"]+data_combine["loss3"])/3

# %%
data_combine["acc_mean"] = (data_combine["acc1"]+data_combine["acc2"]+data_combine["acc3"])/3

# %%
data_combine.sort_values(axis=0, by="loss_mean", ascending=True).head(20)
# Out:
#     Unnamed: 0  momentum  learning rate  ...  reg_penalty  loss_mean  acc_mean
# 13          13       0.6           0.10  ...       0.0001   0.922544  0.736353
# 2            2       0.6           0.01  ...       0.0001   0.923988  0.742160
# 1            1       0.7           0.01  ...       0.0001   0.956880  0.736353
# 13          13       0.6           0.10  ...       0.0001   0.971433  0.745645
# 12          12       0.7           0.10  ...       0.0001   0.975042  0.717770
# 22          22       0.6           0.01  ...       0.0001   0.998016  0.707317
# 2            2       0.7           0.01  ...       0.0001   1.000025  0.699187
# 19          19       0.7           0.01  ...       0.0001   1.004495  0.706156
# 4            4       0.6           0.01  ...       0.0001   1.005263  0.744483
# 21          21       0.7           0.01  ...       0.0001   1.013588  0.734030
# 6            6       0.7           0.10  ...       0.0010   1.028249  0.734030
# 33          33       0.6           0.10  ...       0.0001   1.038209  0.709640
# 3            3       0.7           0.01  ...       0.0001   1.049354  0.747967
# 9            9       0.6           0.10  ...       0.0010   1.056368  0.730546
# 18          18       0.7           0.10  ...       0.0100   1.059237  0.655052
# 10          10       0.7           0.01  ...       0.0001   1.063625  0.692218
# 12          12       0.7           0.10  ...       0.0001   1.063728  0.706156
# 1            1       0.6           0.10  ...       0.0100   1.075759  0.655052
# 19          19       0.6           0.10  ...       0.0100   1.078781  0.632985
# 20          20       0.6           0.01  ...       0.0001   1.083096  0.678281
#
# [20 rows x 16 columns]
