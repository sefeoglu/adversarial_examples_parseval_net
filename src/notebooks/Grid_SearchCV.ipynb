# %% [markdown]
# <a href="https://colab.research.google.com/github/sefeoglu/AE_Parseval_Network/blob/develop/src/notebooks/Grid_SearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gzip
import pickle
import numpy as np
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from itertools import product
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from wresnet import WideResidualNetwork
import tensorflow
import cv2
import json

# %%
def read_data():
    with open("data.pz", 'rb') as file_:
        with gzip.GzipFile(fileobj=file_) as gzf:
            data = pickle.load(gzf, encoding='latin1', fix_imports=True)
    new_data_X = []
    Y_data = []
    for row in data:
        new_data_X.append(cv2.resize(row['crop'], (32,32)))
        Y_data.append(row['label'])
    new_data_X = np.array(new_data_X)

    return new_data_X, Y_data

# %%
def preprocessing():
    # creating initial dataframe
    X, Y = read_data()
    y_df = pd.DataFrame(Y, columns=['Label'])
    labelencoder = LabelEncoder()
    y_df['Categrory'] = labelencoder.fit_transform(y_df['Label'])


    img_rows, img_cols = X[0].shape


    # transform data set
    if K.image_data_format() == 'channels_first':
        X = X.reshape(X.shape[0], 1, img_rows, img_cols)
        input_shape = (1, img_rows, img_cols)
    else:
        X = X.reshape(X.shape[0], img_rows, img_cols, 1)
        input_shape = (img_rows, img_cols, 1)
    Y_cat = to_categorical(y_df['Categrory'])
    return X, Y_cat

# %%
import tensorflow
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD

class ModelSelection(object):
    def __init__(self):
        pass
    def KFold_GridSearchCV(self, input_dim, X, Y, X_test, y_test, combinations, filename="log.csv", acc_loss_json="hist.json"):
         # create containers for resulting data
         
        
        res_df = pd.DataFrame(columns=['momentum','learning rate','batch size',
                                      'loss1', 'acc1','loss2', 'acc2','loss3', 'acc3'])
        generator = tensorflow.keras.preprocessing.image.ImageDataGenerator(rotation_range=10,
                               width_shift_range=5./32,
                               height_shift_range=5./32,)
        hist_dict_global = {}
        f=open(acc_loss_json, "a+")
        for i, combination in enumerate(combinations):
            kf = KFold(n_splits=3, random_state=42, shuffle=False)
            metrics_dict = {}
  
            for j, (train_index, test_index) in enumerate(kf.split(X)):
               if i<10:
                X_train, X_val = X[train_index], X[test_index]
                y_train, y_val = Y[train_index], Y[test_index]
                wresnet_ins = WideResidualNetwork(combination[2], combination[0], in_dim,combination[4], nb_classes=4, N=2, k=2, dropout=0.0)
                model = wresnet_ins.create_wide_residual_network()
                opt = tensorflow.keras.optimizers.SGD(learning_rate=combination[0])
                model.compile(loss='categorical_crossentropy', optimizer=opt, metrics= ['accuracy'])
                hist = model.fit_generator(generator.flow(X_train, y_train, batch_size=combination[1]), steps_per_epoch=len(X_train) // combination[1], epochs=combination[3],
                                    validation_data=(X_val, y_val),
                                    validation_steps=len(X_val) // combination[1],)
                loss, acc = model.evaluate(X_test, y_test)

                metrics_dict[j+1] = {"loss": loss, "acc": acc, "epoch_stopped": combination[3]}
                graph_loss_acc = {"id": i, "com":j+1, "val_acc":hist.history["val_accuracy"], "train_acc":hist.history["accuracy"],
                                  "val_loss":hist.history["val_loss"], "train_loss":hist.history["loss"], "epoch_stopped": combination[3], 'learning rate': combination[0],
                                  'batch size': combination[1], 'reg_penalty': combination[2]}
                json.dump(graph_loss_acc, f, ensure_ascii=False, indent=4)

            if i <10:
              row = {'momentum': combination[4],'learning rate': combination[0],
                        'batch size': combination[1], 'reg_penalty': combination[2],
                        'epoch_stopped1': metrics_dict[1]["epoch_stopped"], 
                        'loss1': metrics_dict[1]["loss"],'acc1': metrics_dict[1]["acc"],
                        'acc1': metrics_dict[1]["acc"],'epoch_stopped2': metrics_dict[2]["epoch_stopped"],
                        'loss2': metrics_dict[2]["loss"],'acc2': metrics_dict[2]["acc"],
                        'epoch_stopped3': metrics_dict[3]["epoch_stopped"],
                        'loss3': metrics_dict[3]["loss"], 'acc3': metrics_dict[3]["acc"]}
              res_df = res_df.append(row , ignore_index=True)
              res_df.to_csv(filename, sep=";")

# %%
if __name__ == "__main__":
    learning_rate = [0.1, 0.01]
    batch_size = [64,128,256]
    reg_penalty = [0.01, 0.001, 0.0001]
    epochs = [50,100,150]
    momentum = [0.9]
    in_dim = (32,32,1)
    grid_result = "grid_16_2.csv"
    acc_loss_json = "history.json"

    # create list of all different parameter combinations
    param_grid = dict(learning_rate = learning_rate, batch_size = batch_size, 
                      reg_penalty = reg_penalty, epochs = epochs, momentum=momentum)
    combinations = list(product(*param_grid.values()))
    X, Y = preprocessing()
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.1, shuffle=False)
    print(combinations)
    instance  = ModelSelection()
    instance.KFold_GridSearchCV(in_dim,X_train,y_train,X_test, y_test, combinations, grid_result, acc_loss_json)
# Out:
# [(0.1, 64, 0.01, 50, 0.9), (0.1, 64, 0.01, 100, 0.9), (0.1, 64, 0.01, 150, 0.9), (0.1, 64, 0.001, 50, 0.9), (0.1, 64, 0.001, 100, 0.9), (0.1, 64, 0.001, 150, 0.9), (0.1, 64, 0.0001, 50, 0.9), (0.1, 64, 0.0001, 100, 0.9), (0.1, 64, 0.0001, 150, 0.9), (0.1, 128, 0.01, 50, 0.9), (0.1, 128, 0.01, 100, 0.9), (0.1, 128, 0.01, 150, 0.9), (0.1, 128, 0.001, 50, 0.9), (0.1, 128, 0.001, 100, 0.9), (0.1, 128, 0.001, 150, 0.9), (0.1, 128, 0.0001, 50, 0.9), (0.1, 128, 0.0001, 100, 0.9), (0.1, 128, 0.0001, 150, 0.9), (0.1, 256, 0.01, 50, 0.9), (0.1, 256, 0.01, 100, 0.9), (0.1, 256, 0.01, 150, 0.9), (0.1, 256, 0.001, 50, 0.9), (0.1, 256, 0.001, 100, 0.9), (0.1, 256, 0.001, 150, 0.9), (0.1, 256, 0.0001, 50, 0.9), (0.1, 256, 0.0001, 100, 0.9), (0.1, 256, 0.0001, 150, 0.9), (0.01, 64, 0.01, 50, 0.9), (0.01, 64, 0.01, 100, 0.9), (0.01, 64, 0.01, 150, 0.9), (0.01, 64, 0.001, 50, 0.9), (0.01, 64, 0.001, 100, 0.9), (0.01, 64, 0.001, 150, 0.9), (0.01, 64, 0.0001, 50, 0.9), (0.01, 64, 0.0001, 100, 0.9), (0.01, 64, 0.0001, 150, 0.9), (0.01, 128, 0.01, 50, 0.9), (0.01, 128, 0.01, 100, 0.9), (0.01, 128, 0.01, 150, 0.9), (0.01, 128, 0.001, 50, 0.9), (0.01, 128, 0.001, 100, 0.9), (0.01, 128, 0.001, 150, 0.9), (0.01, 128, 0.0001, 50, 0.9), (0.01, 128, 0.0001, 100, 0.9), (0.01, 128, 0.0001, 150, 0.9), (0.01, 256, 0.01, 50, 0.9), (0.01, 256, 0.01, 100, 0.9), (0.01, 256, 0.01, 150, 0.9), (0.01, 256, 0.001, 50, 0.9), (0.01, 256, 0.001, 100, 0.9), (0.01, 256, 0.001, 150, 0.9), (0.01, 256, 0.0001, 50, 0.9), (0.01, 256, 0.0001, 100, 0.9), (0.01, 256, 0.0001, 150, 0.9)]
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/50
# 53/53 [==============================] - 3s 61ms/step - loss: 21.9660 - accuracy: 0.3079 - val_loss: 19.7801 - val_accuracy: 0.3943
# Epoch 2/50
# 53/53 [==============================] - 3s 50ms/step - loss: 17.9872 - accuracy: 0.3459 - val_loss: 16.2485 - val_accuracy: 0.3535
# Epoch 3/50
# 53/53 [==============================] - 3s 51ms/step - loss: 14.7724 - accuracy: 0.3367 - val_loss: 13.3939 - val_accuracy: 0.3861
# Epoch 4/50
# 53/53 [==============================] - 3s 50ms/step - loss: 12.1954 - accuracy: 0.3412 - val_loss: 11.0030 - val_accuracy: 0.3891
# Epoch 5/50
# 53/53 [==============================] - 3s 50ms/step - loss: 10.1011 - accuracy: 0.3667 - val_loss: 9.2702 - val_accuracy: 0.3168
# Epoch 6/50
# 53/53 [==============================] - 3s 50ms/step - loss: 8.3916 - accuracy: 0.3800 - val_loss: 7.6608 - val_accuracy: 0.3949
# Epoch 7/50
# 53/53 [==============================] - 3s 50ms/step - loss: 7.0283 - accuracy: 0.3919 - val_loss: 6.5121 - val_accuracy: 0.3128
# Epoch 8/50
# 53/53 [==============================] - 3s 50ms/step - loss: 5.9202 - accuracy: 0.4035 - val_loss: 5.9573 - val_accuracy: 0.2440
# Epoch 9/50
# 53/53 [==============================] - 3s 50ms/step - loss: 5.0056 - accuracy: 0.4151 - val_loss: 4.6701 - val_accuracy: 0.4217
# Epoch 10/50
# 53/53 [==============================] - 3s 50ms/step - loss: 4.2662 - accuracy: 0.4614 - val_loss: 9.9258 - val_accuracy: 0.3407
# Epoch 11/50
# 53/53 [==============================] - 3s 50ms/step - loss: 3.6796 - accuracy: 0.4798 - val_loss: 3.6229 - val_accuracy: 0.4083
# Epoch 12/50
# 53/53 [==============================] - 3s 50ms/step - loss: 3.1829 - accuracy: 0.5015 - val_loss: 2.9732 - val_accuracy: 0.5189
# Epoch 13/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.8152 - accuracy: 0.4973 - val_loss: 2.6817 - val_accuracy: 0.4950
# Epoch 14/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.4664 - accuracy: 0.5338 - val_loss: 2.4584 - val_accuracy: 0.4991
# Epoch 15/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.2109 - accuracy: 0.5285 - val_loss: 2.4258 - val_accuracy: 0.3955
# Epoch 16/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.0112 - accuracy: 0.5362 - val_loss: 1.9378 - val_accuracy: 0.5574
# Epoch 17/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.8221 - accuracy: 0.5597 - val_loss: 3.4058 - val_accuracy: 0.3861
# Epoch 18/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.7213 - accuracy: 0.5422 - val_loss: 2.1463 - val_accuracy: 0.3658
# Epoch 19/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.5700 - accuracy: 0.5802 - val_loss: 2.5544 - val_accuracy: 0.3838
# Epoch 20/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.4748 - accuracy: 0.5748 - val_loss: 2.0015 - val_accuracy: 0.4042
# Epoch 21/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.4039 - accuracy: 0.5790 - val_loss: 1.4665 - val_accuracy: 0.5475
# Epoch 22/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.3220 - accuracy: 0.6042 - val_loss: 1.4801 - val_accuracy: 0.5556
# Epoch 23/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.2838 - accuracy: 0.6012 - val_loss: 1.4984 - val_accuracy: 0.4950
# Epoch 24/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.2394 - accuracy: 0.6200 - val_loss: 1.3271 - val_accuracy: 0.5778
# Epoch 25/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1896 - accuracy: 0.6360 - val_loss: 1.1967 - val_accuracy: 0.6366
# Epoch 26/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1503 - accuracy: 0.6485 - val_loss: 1.8857 - val_accuracy: 0.4665
# Epoch 27/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1226 - accuracy: 0.6440 - val_loss: 1.2144 - val_accuracy: 0.6261
# Epoch 28/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0842 - accuracy: 0.6580 - val_loss: 1.2725 - val_accuracy: 0.5882
# Epoch 29/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0799 - accuracy: 0.6473 - val_loss: 2.0322 - val_accuracy: 0.4595
# Epoch 30/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0682 - accuracy: 0.6520 - val_loss: 1.1180 - val_accuracy: 0.6453
# Epoch 31/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0456 - accuracy: 0.6639 - val_loss: 1.1623 - val_accuracy: 0.6255
# Epoch 32/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0414 - accuracy: 0.6734 - val_loss: 1.1863 - val_accuracy: 0.5929
# Epoch 33/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0398 - accuracy: 0.6740 - val_loss: 1.3036 - val_accuracy: 0.6028
# Epoch 34/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0333 - accuracy: 0.6761 - val_loss: 1.3812 - val_accuracy: 0.5434
# Epoch 35/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0249 - accuracy: 0.6752 - val_loss: 1.1043 - val_accuracy: 0.6476
# Epoch 36/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9953 - accuracy: 0.6918 - val_loss: 1.2675 - val_accuracy: 0.5533
# Epoch 37/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9951 - accuracy: 0.6921 - val_loss: 1.1070 - val_accuracy: 0.6383
# Epoch 38/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0172 - accuracy: 0.6734 - val_loss: 1.6972 - val_accuracy: 0.4607
# Epoch 39/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0093 - accuracy: 0.6787 - val_loss: 1.2211 - val_accuracy: 0.6179
# Epoch 40/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9823 - accuracy: 0.7013 - val_loss: 1.1464 - val_accuracy: 0.6424
# Epoch 41/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9952 - accuracy: 0.6915 - val_loss: 1.2404 - val_accuracy: 0.5871
# Epoch 42/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9976 - accuracy: 0.6998 - val_loss: 1.3664 - val_accuracy: 0.5556
# Epoch 43/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9829 - accuracy: 0.6983 - val_loss: 1.3730 - val_accuracy: 0.6063
# Epoch 44/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9915 - accuracy: 0.7090 - val_loss: 1.7473 - val_accuracy: 0.5475
# Epoch 45/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9851 - accuracy: 0.6977 - val_loss: 1.1045 - val_accuracy: 0.6482
# Epoch 46/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9715 - accuracy: 0.7141 - val_loss: 1.2196 - val_accuracy: 0.6156
# Epoch 47/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9741 - accuracy: 0.7067 - val_loss: 1.0655 - val_accuracy: 0.6686
# Epoch 48/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9652 - accuracy: 0.7135 - val_loss: 1.2175 - val_accuracy: 0.6523
# Epoch 49/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9440 - accuracy: 0.7215 - val_loss: 1.1583 - val_accuracy: 0.6500
# Epoch 50/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9887 - accuracy: 0.7043 - val_loss: 1.0741 - val_accuracy: 0.6884
# 18/18 [==============================] - 0s 10ms/step - loss: 0.9638 - accuracy: 0.7330
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 22.0322 - accuracy: 0.3107WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0041s vs `on_test_batch_end` time: 0.0087s). Check your callbacks.
# 53/53 [==============================] - 3s 58ms/step - loss: 21.9910 - accuracy: 0.3143 - val_loss: 19.8193 - val_accuracy: 0.3374
# Epoch 2/50
# 53/53 [==============================] - 3s 50ms/step - loss: 17.9845 - accuracy: 0.3690 - val_loss: 16.2468 - val_accuracy: 0.3677
# Epoch 3/50
# 53/53 [==============================] - 3s 50ms/step - loss: 14.7432 - accuracy: 0.3826 - val_loss: 13.5290 - val_accuracy: 0.2477
# Epoch 4/50
# 53/53 [==============================] - 3s 50ms/step - loss: 12.1658 - accuracy: 0.3930 - val_loss: 11.0653 - val_accuracy: 0.3677
# Epoch 5/50
# 53/53 [==============================] - 3s 50ms/step - loss: 10.0715 - accuracy: 0.3989 - val_loss: 9.2012 - val_accuracy: 0.3689
# Epoch 6/50
# 53/53 [==============================] - 3s 50ms/step - loss: 8.3679 - accuracy: 0.4055 - val_loss: 7.6922 - val_accuracy: 0.4044
# Epoch 7/50
# 53/53 [==============================] - 3s 50ms/step - loss: 7.0064 - accuracy: 0.4224 - val_loss: 6.4388 - val_accuracy: 0.4120
# Epoch 8/50
# 53/53 [==============================] - 3s 50ms/step - loss: 5.8820 - accuracy: 0.4506 - val_loss: 5.4390 - val_accuracy: 0.4487
# Epoch 9/50
# 53/53 [==============================] - 3s 50ms/step - loss: 4.9747 - accuracy: 0.4844 - val_loss: 4.6582 - val_accuracy: 0.4248
# Epoch 10/50
# 53/53 [==============================] - 3s 50ms/step - loss: 4.2416 - accuracy: 0.5079 - val_loss: 4.0862 - val_accuracy: 0.3223
# Epoch 11/50
# 53/53 [==============================] - 3s 50ms/step - loss: 3.6398 - accuracy: 0.5096 - val_loss: 3.5722 - val_accuracy: 0.3485
# Epoch 12/50
# 53/53 [==============================] - 3s 50ms/step - loss: 3.1482 - accuracy: 0.5286 - val_loss: 3.0889 - val_accuracy: 0.4242
# Epoch 13/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.7548 - accuracy: 0.5408 - val_loss: 3.4372 - val_accuracy: 0.3864
# Epoch 14/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.4271 - accuracy: 0.5465 - val_loss: 2.3812 - val_accuracy: 0.5111
# Epoch 15/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.1679 - accuracy: 0.5607 - val_loss: 2.2506 - val_accuracy: 0.4779
# Epoch 16/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.9346 - accuracy: 0.5744 - val_loss: 2.2960 - val_accuracy: 0.3188
# Epoch 17/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.7695 - accuracy: 0.5853 - val_loss: 2.0651 - val_accuracy: 0.3753
# Epoch 18/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.6203 - accuracy: 0.6014 - val_loss: 1.7688 - val_accuracy: 0.5093
# Epoch 19/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.4930 - accuracy: 0.6150 - val_loss: 1.8342 - val_accuracy: 0.4738
# Epoch 20/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.4133 - accuracy: 0.6215 - val_loss: 1.5774 - val_accuracy: 0.5000
# Epoch 21/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.3211 - accuracy: 0.6353 - val_loss: 1.4982 - val_accuracy: 0.5367
# Epoch 22/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.2429 - accuracy: 0.6527 - val_loss: 1.3255 - val_accuracy: 0.6002
# Epoch 23/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1991 - accuracy: 0.6533 - val_loss: 1.3160 - val_accuracy: 0.5962
# Epoch 24/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1599 - accuracy: 0.6566 - val_loss: 1.5465 - val_accuracy: 0.4814
# Epoch 25/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1210 - accuracy: 0.6690 - val_loss: 1.6772 - val_accuracy: 0.4155
# Epoch 26/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0936 - accuracy: 0.6809 - val_loss: 1.2710 - val_accuracy: 0.5874
# Epoch 27/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0786 - accuracy: 0.6696 - val_loss: 1.8759 - val_accuracy: 0.4761
# Epoch 28/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0425 - accuracy: 0.6901 - val_loss: 1.3789 - val_accuracy: 0.5629
# Epoch 29/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0192 - accuracy: 0.6952 - val_loss: 1.1240 - val_accuracy: 0.6503
# Epoch 30/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0065 - accuracy: 0.7094 - val_loss: 1.5297 - val_accuracy: 0.5058
# Epoch 31/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0093 - accuracy: 0.6984 - val_loss: 1.3194 - val_accuracy: 0.5653
# Epoch 32/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9959 - accuracy: 0.7041 - val_loss: 1.1326 - val_accuracy: 0.6294
# Epoch 33/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0050 - accuracy: 0.6963 - val_loss: 1.3158 - val_accuracy: 0.6090
# Epoch 34/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9676 - accuracy: 0.7067 - val_loss: 1.7717 - val_accuracy: 0.4126
# Epoch 35/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9580 - accuracy: 0.7237 - val_loss: 1.5474 - val_accuracy: 0.5239
# Epoch 36/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9431 - accuracy: 0.7223 - val_loss: 1.6417 - val_accuracy: 0.5216
# Epoch 37/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9615 - accuracy: 0.7245 - val_loss: 1.1940 - val_accuracy: 0.6364
# Epoch 38/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9540 - accuracy: 0.7213 - val_loss: 1.3857 - val_accuracy: 0.5956
# Epoch 39/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9307 - accuracy: 0.7370 - val_loss: 1.3906 - val_accuracy: 0.5600
# Epoch 40/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9651 - accuracy: 0.7174 - val_loss: 1.4499 - val_accuracy: 0.5163
# Epoch 41/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9356 - accuracy: 0.7335 - val_loss: 1.2291 - val_accuracy: 0.6282
# Epoch 42/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9379 - accuracy: 0.7266 - val_loss: 1.1966 - val_accuracy: 0.6294
# Epoch 43/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9406 - accuracy: 0.7421 - val_loss: 1.2404 - val_accuracy: 0.5997
# Epoch 44/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9294 - accuracy: 0.7376 - val_loss: 1.4141 - val_accuracy: 0.5583
# Epoch 45/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9255 - accuracy: 0.7412 - val_loss: 1.6328 - val_accuracy: 0.5542
# Epoch 46/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9433 - accuracy: 0.7397 - val_loss: 1.3755 - val_accuracy: 0.5944
# Epoch 47/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9589 - accuracy: 0.7257 - val_loss: 1.2012 - val_accuracy: 0.6334
# Epoch 48/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9185 - accuracy: 0.7397 - val_loss: 1.3059 - val_accuracy: 0.5787
# Epoch 49/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9460 - accuracy: 0.7329 - val_loss: 1.2721 - val_accuracy: 0.5787
# Epoch 50/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9129 - accuracy: 0.7432 - val_loss: 1.3510 - val_accuracy: 0.6031
# 18/18 [==============================] - 0s 10ms/step - loss: 1.1881 - accuracy: 0.6318
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 22.0572 - accuracy: 0.3212WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0043s vs `on_test_batch_end` time: 0.0090s). Check your callbacks.
# 53/53 [==============================] - 3s 59ms/step - loss: 22.0572 - accuracy: 0.3212 - val_loss: 19.8820 - val_accuracy: 0.3153
# Epoch 2/50
# 53/53 [==============================] - 3s 50ms/step - loss: 18.0594 - accuracy: 0.3645 - val_loss: 16.3006 - val_accuracy: 0.3462
# Epoch 3/50
# 53/53 [==============================] - 3s 51ms/step - loss: 14.8261 - accuracy: 0.3666 - val_loss: 13.4380 - val_accuracy: 0.3240
# Epoch 4/50
# 53/53 [==============================] - 3s 50ms/step - loss: 12.2177 - accuracy: 0.3808 - val_loss: 11.1292 - val_accuracy: 0.3275
# Epoch 5/50
# 53/53 [==============================] - 3s 50ms/step - loss: 10.1151 - accuracy: 0.3879 - val_loss: 9.2337 - val_accuracy: 0.3409
# Epoch 6/50
# 53/53 [==============================] - 3s 51ms/step - loss: 8.4179 - accuracy: 0.3960 - val_loss: 7.8937 - val_accuracy: 0.2599
# Epoch 7/50
# 53/53 [==============================] - 3s 50ms/step - loss: 7.0284 - accuracy: 0.4161 - val_loss: 6.5058 - val_accuracy: 0.3875
# Epoch 8/50
# 53/53 [==============================] - 3s 50ms/step - loss: 5.9266 - accuracy: 0.4265 - val_loss: 5.5175 - val_accuracy: 0.3613
# Epoch 9/50
# 53/53 [==============================] - 3s 50ms/step - loss: 5.0141 - accuracy: 0.4571 - val_loss: 4.6545 - val_accuracy: 0.4021
# Epoch 10/50
# 53/53 [==============================] - 3s 51ms/step - loss: 4.2698 - accuracy: 0.4835 - val_loss: 4.0347 - val_accuracy: 0.3479
# Epoch 11/50
# 53/53 [==============================] - 3s 51ms/step - loss: 3.6639 - accuracy: 0.4972 - val_loss: 3.6096 - val_accuracy: 0.3432
# Epoch 12/50
# 53/53 [==============================] - 3s 50ms/step - loss: 3.1612 - accuracy: 0.5191 - val_loss: 3.0477 - val_accuracy: 0.4318
# Epoch 13/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.7686 - accuracy: 0.5165 - val_loss: 2.6646 - val_accuracy: 0.4872
# Epoch 14/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.4362 - accuracy: 0.5438 - val_loss: 2.8363 - val_accuracy: 0.4126
# Epoch 15/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.1796 - accuracy: 0.5488 - val_loss: 2.2293 - val_accuracy: 0.4866
# Epoch 16/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.9521 - accuracy: 0.5681 - val_loss: 2.0395 - val_accuracy: 0.4639
# Epoch 17/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.7711 - accuracy: 0.5928 - val_loss: 2.2513 - val_accuracy: 0.3747
# Epoch 18/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.6359 - accuracy: 0.5880 - val_loss: 2.6159 - val_accuracy: 0.2622
# Epoch 19/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.5296 - accuracy: 0.5847 - val_loss: 1.7979 - val_accuracy: 0.4272
# Epoch 20/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.4121 - accuracy: 0.6186 - val_loss: 1.7069 - val_accuracy: 0.4837
# Epoch 21/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.3226 - accuracy: 0.6263 - val_loss: 2.1499 - val_accuracy: 0.3584
# Epoch 22/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2504 - accuracy: 0.6397 - val_loss: 1.5578 - val_accuracy: 0.4924
# Epoch 23/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2094 - accuracy: 0.6480 - val_loss: 1.3171 - val_accuracy: 0.5711
# Epoch 24/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1601 - accuracy: 0.6610 - val_loss: 2.3703 - val_accuracy: 0.3409
# Epoch 25/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.1278 - accuracy: 0.6610 - val_loss: 1.2514 - val_accuracy: 0.5956
# Epoch 26/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0941 - accuracy: 0.6701 - val_loss: 1.7985 - val_accuracy: 0.4930
# Epoch 27/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.0621 - accuracy: 0.6854 - val_loss: 1.2359 - val_accuracy: 0.6125
# Epoch 28/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0350 - accuracy: 0.6895 - val_loss: 1.5746 - val_accuracy: 0.4709
# Epoch 29/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0179 - accuracy: 0.7011 - val_loss: 1.2522 - val_accuracy: 0.5618
# Epoch 30/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0201 - accuracy: 0.6889 - val_loss: 1.2982 - val_accuracy: 0.5490
# Epoch 31/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9889 - accuracy: 0.7002 - val_loss: 1.9482 - val_accuracy: 0.3980
# Epoch 32/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9893 - accuracy: 0.7035 - val_loss: 2.3100 - val_accuracy: 0.3001
# Epoch 33/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9859 - accuracy: 0.7041 - val_loss: 1.2569 - val_accuracy: 0.5682
# Epoch 34/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9686 - accuracy: 0.7115 - val_loss: 1.7121 - val_accuracy: 0.4540
# Epoch 35/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9845 - accuracy: 0.7070 - val_loss: 1.3135 - val_accuracy: 0.5612
# Epoch 36/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9543 - accuracy: 0.7162 - val_loss: 1.2296 - val_accuracy: 0.6276
# Epoch 37/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9438 - accuracy: 0.7219 - val_loss: 1.8058 - val_accuracy: 0.4924
# Epoch 38/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9196 - accuracy: 0.7340 - val_loss: 1.3556 - val_accuracy: 0.5828
# Epoch 39/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9525 - accuracy: 0.7100 - val_loss: 1.8786 - val_accuracy: 0.2704
# Epoch 40/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9445 - accuracy: 0.7308 - val_loss: 1.3031 - val_accuracy: 0.5892
# Epoch 41/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9469 - accuracy: 0.7231 - val_loss: 1.3068 - val_accuracy: 0.5804
# Epoch 42/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9192 - accuracy: 0.7352 - val_loss: 1.1912 - val_accuracy: 0.6265
# Epoch 43/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9364 - accuracy: 0.7278 - val_loss: 1.6588 - val_accuracy: 0.4866
# Epoch 44/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9362 - accuracy: 0.7266 - val_loss: 1.3865 - val_accuracy: 0.5577
# Epoch 45/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9435 - accuracy: 0.7243 - val_loss: 1.2329 - val_accuracy: 0.6212
# Epoch 46/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9110 - accuracy: 0.7394 - val_loss: 1.1770 - val_accuracy: 0.6270
# Epoch 47/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9132 - accuracy: 0.7397 - val_loss: 1.3716 - val_accuracy: 0.5857
# Epoch 48/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9289 - accuracy: 0.7403 - val_loss: 1.1767 - val_accuracy: 0.6317
# Epoch 49/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9145 - accuracy: 0.7444 - val_loss: 1.1751 - val_accuracy: 0.6428
# Epoch 50/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9029 - accuracy: 0.7557 - val_loss: 1.1341 - val_accuracy: 0.6573
# 18/18 [==============================] - 0s 10ms/step - loss: 0.9562 - accuracy: 0.7225
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/100
# 53/53 [==============================] - 3s 61ms/step - loss: 22.0017 - accuracy: 0.3005 - val_loss: 19.8212 - val_accuracy: 0.4048
# Epoch 2/100
# 53/53 [==============================] - 3s 51ms/step - loss: 18.0153 - accuracy: 0.3412 - val_loss: 17.7411 - val_accuracy: 0.2277
# Epoch 3/100
# 53/53 [==============================] - 3s 51ms/step - loss: 14.8067 - accuracy: 0.3263 - val_loss: 13.3510 - val_accuracy: 0.3564
# Epoch 4/100
# 53/53 [==============================] - 3s 51ms/step - loss: 12.2244 - accuracy: 0.3334 - val_loss: 11.0548 - val_accuracy: 0.3786
# Epoch 5/100
# 53/53 [==============================] - 3s 51ms/step - loss: 10.1007 - accuracy: 0.3652 - val_loss: 9.1862 - val_accuracy: 0.3570
# Epoch 6/100
# 53/53 [==============================] - 3s 51ms/step - loss: 8.4111 - accuracy: 0.3768 - val_loss: 7.7170 - val_accuracy: 0.3465
# Epoch 7/100
# 53/53 [==============================] - 3s 51ms/step - loss: 7.0399 - accuracy: 0.3901 - val_loss: 6.4622 - val_accuracy: 0.3850
# Epoch 8/100
# 53/53 [==============================] - 3s 52ms/step - loss: 5.9289 - accuracy: 0.3913 - val_loss: 5.4264 - val_accuracy: 0.3891
# Epoch 9/100
# 53/53 [==============================] - 3s 52ms/step - loss: 5.0216 - accuracy: 0.4044 - val_loss: 4.8025 - val_accuracy: 0.2930
# Epoch 10/100
# 53/53 [==============================] - 3s 52ms/step - loss: 4.3048 - accuracy: 0.4053 - val_loss: 3.9759 - val_accuracy: 0.4193
# Epoch 11/100
# 53/53 [==============================] - 3s 51ms/step - loss: 3.7129 - accuracy: 0.4181 - val_loss: 3.4622 - val_accuracy: 0.3826
# Epoch 12/100
# 53/53 [==============================] - 3s 52ms/step - loss: 3.2343 - accuracy: 0.4222 - val_loss: 3.1958 - val_accuracy: 0.3885
# Epoch 13/100
# 53/53 [==============================] - 3s 52ms/step - loss: 2.8268 - accuracy: 0.4724 - val_loss: 2.9178 - val_accuracy: 0.3593
# Epoch 14/100
# 53/53 [==============================] - 3s 51ms/step - loss: 2.5323 - accuracy: 0.4754 - val_loss: 2.4181 - val_accuracy: 0.4881
# Epoch 15/100
# 53/53 [==============================] - 3s 50ms/step - loss: 2.2454 - accuracy: 0.4961 - val_loss: 2.3467 - val_accuracy: 0.3809
# Epoch 16/100
# 53/53 [==============================] - 3s 51ms/step - loss: 2.0474 - accuracy: 0.5053 - val_loss: 2.0797 - val_accuracy: 0.4281
# Epoch 17/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.8850 - accuracy: 0.5050 - val_loss: 1.9120 - val_accuracy: 0.4659
# Epoch 18/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.7147 - accuracy: 0.5389 - val_loss: 2.0908 - val_accuracy: 0.3873
# Epoch 19/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.6230 - accuracy: 0.5306 - val_loss: 1.6102 - val_accuracy: 0.5341
# Epoch 20/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.5050 - accuracy: 0.5597 - val_loss: 1.6450 - val_accuracy: 0.5498
# Epoch 21/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.4219 - accuracy: 0.5727 - val_loss: 1.4214 - val_accuracy: 0.5667
# Epoch 22/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.3450 - accuracy: 0.5840 - val_loss: 1.4460 - val_accuracy: 0.5917
# Epoch 23/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2968 - accuracy: 0.5912 - val_loss: 1.7730 - val_accuracy: 0.3751
# Epoch 24/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.2426 - accuracy: 0.6027 - val_loss: 1.6063 - val_accuracy: 0.4193
# Epoch 25/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2053 - accuracy: 0.6116 - val_loss: 1.7443 - val_accuracy: 0.4875
# Epoch 26/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.1605 - accuracy: 0.6283 - val_loss: 2.1747 - val_accuracy: 0.4432
# Epoch 27/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.1316 - accuracy: 0.6324 - val_loss: 2.4127 - val_accuracy: 0.4222
# Epoch 28/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.1128 - accuracy: 0.6413 - val_loss: 1.1863 - val_accuracy: 0.6459
# Epoch 29/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0882 - accuracy: 0.6583 - val_loss: 1.2795 - val_accuracy: 0.5906
# Epoch 30/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0762 - accuracy: 0.6657 - val_loss: 1.2139 - val_accuracy: 0.6057
# Epoch 31/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0498 - accuracy: 0.6757 - val_loss: 1.5068 - val_accuracy: 0.5579
# Epoch 32/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0379 - accuracy: 0.6784 - val_loss: 1.3542 - val_accuracy: 0.5323
# Epoch 33/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0524 - accuracy: 0.6675 - val_loss: 1.1098 - val_accuracy: 0.6669
# Epoch 34/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0348 - accuracy: 0.6707 - val_loss: 1.9930 - val_accuracy: 0.4362
# Epoch 35/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0169 - accuracy: 0.6850 - val_loss: 1.1857 - val_accuracy: 0.6232
# Epoch 36/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0118 - accuracy: 0.6915 - val_loss: 1.2529 - val_accuracy: 0.6401
# Epoch 37/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0185 - accuracy: 0.6850 - val_loss: 1.1122 - val_accuracy: 0.6471
# Epoch 38/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9920 - accuracy: 0.6998 - val_loss: 1.1037 - val_accuracy: 0.6540
# Epoch 39/100
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0066 - accuracy: 0.6921 - val_loss: 1.3947 - val_accuracy: 0.5218
# Epoch 40/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9910 - accuracy: 0.7007 - val_loss: 1.0146 - val_accuracy: 0.6750
# Epoch 41/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9928 - accuracy: 0.6930 - val_loss: 1.0310 - val_accuracy: 0.6791
# Epoch 42/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9879 - accuracy: 0.7022 - val_loss: 1.7838 - val_accuracy: 0.4514
# Epoch 43/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9744 - accuracy: 0.7084 - val_loss: 1.1960 - val_accuracy: 0.6476
# Epoch 44/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9783 - accuracy: 0.7052 - val_loss: 1.1153 - val_accuracy: 0.6348
# Epoch 45/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9737 - accuracy: 0.7123 - val_loss: 1.2377 - val_accuracy: 0.6261
# Epoch 46/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9709 - accuracy: 0.7179 - val_loss: 2.2707 - val_accuracy: 0.4916
# Epoch 47/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9837 - accuracy: 0.7064 - val_loss: 1.1394 - val_accuracy: 0.6337
# Epoch 48/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9723 - accuracy: 0.7135 - val_loss: 1.0488 - val_accuracy: 0.6826
# Epoch 49/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9632 - accuracy: 0.7182 - val_loss: 1.5558 - val_accuracy: 0.5510
# Epoch 50/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9820 - accuracy: 0.7185 - val_loss: 1.6650 - val_accuracy: 0.5248
# Epoch 51/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9874 - accuracy: 0.7081 - val_loss: 1.3399 - val_accuracy: 0.5591
# Epoch 52/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9553 - accuracy: 0.7289 - val_loss: 1.1125 - val_accuracy: 0.6535
# Epoch 53/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9599 - accuracy: 0.7221 - val_loss: 1.2497 - val_accuracy: 0.6115
# Epoch 54/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9850 - accuracy: 0.7147 - val_loss: 1.1140 - val_accuracy: 0.6779
# Epoch 55/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9381 - accuracy: 0.7355 - val_loss: 1.0931 - val_accuracy: 0.6983
# Epoch 56/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9761 - accuracy: 0.7289 - val_loss: 1.4909 - val_accuracy: 0.5125
# Epoch 57/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9620 - accuracy: 0.7257 - val_loss: 1.1573 - val_accuracy: 0.6768
# Epoch 58/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9465 - accuracy: 0.7337 - val_loss: 1.1660 - val_accuracy: 0.6453
# Epoch 59/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9420 - accuracy: 0.7346 - val_loss: 1.7800 - val_accuracy: 0.5282
# Epoch 60/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9509 - accuracy: 0.7337 - val_loss: 1.2088 - val_accuracy: 0.6552
# Epoch 61/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9469 - accuracy: 0.7402 - val_loss: 1.1204 - val_accuracy: 0.6768
# Epoch 62/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9553 - accuracy: 0.7350 - val_loss: 1.3143 - val_accuracy: 0.5847
# Epoch 63/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9597 - accuracy: 0.7375 - val_loss: 1.2791 - val_accuracy: 0.6308
# Epoch 64/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9570 - accuracy: 0.7274 - val_loss: 1.1695 - val_accuracy: 0.6558
# Epoch 65/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9638 - accuracy: 0.7295 - val_loss: 1.2759 - val_accuracy: 0.6243
# Epoch 66/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9382 - accuracy: 0.7408 - val_loss: 2.4826 - val_accuracy: 0.4560
# Epoch 67/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9430 - accuracy: 0.7479 - val_loss: 1.6836 - val_accuracy: 0.5510
# Epoch 68/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9415 - accuracy: 0.7464 - val_loss: 1.6817 - val_accuracy: 0.5067
# Epoch 69/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9774 - accuracy: 0.7254 - val_loss: 1.2711 - val_accuracy: 0.6273
# Epoch 70/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9698 - accuracy: 0.7322 - val_loss: 1.9636 - val_accuracy: 0.4892
# Epoch 71/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9546 - accuracy: 0.7375 - val_loss: 1.7598 - val_accuracy: 0.4415
# Epoch 72/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9612 - accuracy: 0.7423 - val_loss: 2.1016 - val_accuracy: 0.4910
# Epoch 73/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9356 - accuracy: 0.7533 - val_loss: 2.2325 - val_accuracy: 0.4630
# Epoch 74/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9449 - accuracy: 0.7402 - val_loss: 1.3505 - val_accuracy: 0.6453
# Epoch 75/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9286 - accuracy: 0.7545 - val_loss: 1.3765 - val_accuracy: 0.5527
# Epoch 76/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9479 - accuracy: 0.7435 - val_loss: 1.2821 - val_accuracy: 0.6441
# Epoch 77/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9582 - accuracy: 0.7417 - val_loss: 2.0506 - val_accuracy: 0.5032
# Epoch 78/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9429 - accuracy: 0.7420 - val_loss: 2.2129 - val_accuracy: 0.4787
# Epoch 79/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9459 - accuracy: 0.7494 - val_loss: 1.2012 - val_accuracy: 0.6727
# Epoch 80/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9415 - accuracy: 0.7455 - val_loss: 1.1890 - val_accuracy: 0.6605
# Epoch 81/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9465 - accuracy: 0.7432 - val_loss: 1.2341 - val_accuracy: 0.6599
# Epoch 82/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9536 - accuracy: 0.7497 - val_loss: 1.1866 - val_accuracy: 0.6727
# Epoch 83/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9533 - accuracy: 0.7464 - val_loss: 1.1389 - val_accuracy: 0.6896
# Epoch 84/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9458 - accuracy: 0.7518 - val_loss: 1.2769 - val_accuracy: 0.6348
# Epoch 85/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9397 - accuracy: 0.7589 - val_loss: 1.1569 - val_accuracy: 0.6599
# Epoch 86/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9317 - accuracy: 0.7503 - val_loss: 1.2108 - val_accuracy: 0.6587
# Epoch 87/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9334 - accuracy: 0.7645 - val_loss: 1.1440 - val_accuracy: 0.6867
# Epoch 88/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9710 - accuracy: 0.7527 - val_loss: 1.3622 - val_accuracy: 0.6191
# Epoch 89/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9260 - accuracy: 0.7651 - val_loss: 1.1376 - val_accuracy: 0.6750
# Epoch 90/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9467 - accuracy: 0.7503 - val_loss: 1.4138 - val_accuracy: 0.5772
# Epoch 91/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9387 - accuracy: 0.7672 - val_loss: 1.1214 - val_accuracy: 0.6966
# Epoch 92/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9223 - accuracy: 0.7663 - val_loss: 2.5976 - val_accuracy: 0.4461
# Epoch 93/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9460 - accuracy: 0.7637 - val_loss: 3.2896 - val_accuracy: 0.3605
# Epoch 94/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9349 - accuracy: 0.7601 - val_loss: 1.5572 - val_accuracy: 0.4916
# Epoch 95/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9269 - accuracy: 0.7687 - val_loss: 1.2532 - val_accuracy: 0.6494
# Epoch 96/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9478 - accuracy: 0.7592 - val_loss: 1.1881 - val_accuracy: 0.6884
# Epoch 97/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9268 - accuracy: 0.7693 - val_loss: 1.2886 - val_accuracy: 0.6395
# Epoch 98/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9466 - accuracy: 0.7533 - val_loss: 1.2426 - val_accuracy: 0.6628
# Epoch 99/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9299 - accuracy: 0.7648 - val_loss: 1.7987 - val_accuracy: 0.5422
# Epoch 100/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9362 - accuracy: 0.7675 - val_loss: 1.2008 - val_accuracy: 0.6791
# 18/18 [==============================] - 0s 10ms/step - loss: 1.0312 - accuracy: 0.7086
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/100
# 53/53 [==============================] - ETA: 0s - loss: 21.9072 - accuracy: 0.3378WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0095s). Check your callbacks.
# 53/53 [==============================] - 3s 62ms/step - loss: 21.9072 - accuracy: 0.3378 - val_loss: 19.7272 - val_accuracy: 0.3374
# Epoch 2/100
# 53/53 [==============================] - 3s 53ms/step - loss: 17.9257 - accuracy: 0.3609 - val_loss: 16.2954 - val_accuracy: 0.2646
# Epoch 3/100
# 53/53 [==============================] - 3s 52ms/step - loss: 14.7261 - accuracy: 0.3704 - val_loss: 13.3549 - val_accuracy: 0.3217
# Epoch 4/100
# 53/53 [==============================] - 3s 53ms/step - loss: 12.1403 - accuracy: 0.3612 - val_loss: 11.0494 - val_accuracy: 0.3438
# Epoch 5/100
# 53/53 [==============================] - 3s 53ms/step - loss: 10.0525 - accuracy: 0.3808 - val_loss: 9.2362 - val_accuracy: 0.3298
# Epoch 6/100
# 53/53 [==============================] - 3s 52ms/step - loss: 8.3628 - accuracy: 0.3877 - val_loss: 7.6782 - val_accuracy: 0.3514
# Epoch 7/100
# 53/53 [==============================] - 3s 53ms/step - loss: 6.9955 - accuracy: 0.3963 - val_loss: 6.4900 - val_accuracy: 0.3543
# Epoch 8/100
# 53/53 [==============================] - 3s 52ms/step - loss: 5.8965 - accuracy: 0.3838 - val_loss: 5.4899 - val_accuracy: 0.3613
# Epoch 9/100
# 53/53 [==============================] - 3s 52ms/step - loss: 5.0031 - accuracy: 0.4022 - val_loss: 4.7119 - val_accuracy: 0.3444
# Epoch 10/100
# 53/53 [==============================] - 3s 52ms/step - loss: 4.2740 - accuracy: 0.4025 - val_loss: 4.0410 - val_accuracy: 0.3526
# Epoch 11/100
# 53/53 [==============================] - 3s 52ms/step - loss: 3.6939 - accuracy: 0.4126 - val_loss: 3.5476 - val_accuracy: 0.3619
# Epoch 12/100
# 53/53 [==============================] - 3s 53ms/step - loss: 3.2351 - accuracy: 0.4084 - val_loss: 3.1107 - val_accuracy: 0.3537
# Epoch 13/100
# 53/53 [==============================] - 3s 52ms/step - loss: 2.8523 - accuracy: 0.4164 - val_loss: 2.7806 - val_accuracy: 0.3642
# Epoch 14/100
# 53/53 [==============================] - 3s 51ms/step - loss: 2.5273 - accuracy: 0.4381 - val_loss: 2.5211 - val_accuracy: 0.3456
# Epoch 15/100
# 53/53 [==============================] - 3s 54ms/step - loss: 2.2653 - accuracy: 0.4720 - val_loss: 2.9533 - val_accuracy: 0.2646
# Epoch 16/100
# 53/53 [==============================] - 3s 54ms/step - loss: 2.0481 - accuracy: 0.4990 - val_loss: 2.0787 - val_accuracy: 0.4120
# Epoch 17/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.8696 - accuracy: 0.5123 - val_loss: 1.8663 - val_accuracy: 0.4854
# Epoch 18/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.7145 - accuracy: 0.5289 - val_loss: 1.7437 - val_accuracy: 0.4779
# Epoch 19/100
# 53/53 [==============================] - 3s 54ms/step - loss: 1.5874 - accuracy: 0.5494 - val_loss: 1.6137 - val_accuracy: 0.5093
# Epoch 20/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.4819 - accuracy: 0.5649 - val_loss: 1.7162 - val_accuracy: 0.4248
# Epoch 21/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.4023 - accuracy: 0.5749 - val_loss: 1.4042 - val_accuracy: 0.5600
# Epoch 22/100
# 53/53 [==============================] - 3s 54ms/step - loss: 1.3192 - accuracy: 0.5868 - val_loss: 1.8094 - val_accuracy: 0.4167
# Epoch 23/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.2637 - accuracy: 0.5990 - val_loss: 1.7304 - val_accuracy: 0.3992
# Epoch 24/100
# 53/53 [==============================] - 3s 54ms/step - loss: 1.2025 - accuracy: 0.6126 - val_loss: 1.3785 - val_accuracy: 0.5519
# Epoch 25/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.1792 - accuracy: 0.6251 - val_loss: 1.2895 - val_accuracy: 0.5390
# Epoch 26/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.1201 - accuracy: 0.6465 - val_loss: 1.2781 - val_accuracy: 0.5559
# Epoch 27/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.1041 - accuracy: 0.6426 - val_loss: 1.2966 - val_accuracy: 0.5175
# Epoch 28/100
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0673 - accuracy: 0.6628 - val_loss: 1.4496 - val_accuracy: 0.4848
# Epoch 29/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.0541 - accuracy: 0.6676 - val_loss: 2.5661 - val_accuracy: 0.3735
# Epoch 30/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.0368 - accuracy: 0.6782 - val_loss: 1.1629 - val_accuracy: 0.6119
# Epoch 31/100
# 53/53 [==============================] - 3s 54ms/step - loss: 1.0506 - accuracy: 0.6673 - val_loss: 1.4157 - val_accuracy: 0.4650
# Epoch 32/100
# 53/53 [==============================] - 3s 53ms/step - loss: 1.0120 - accuracy: 0.6836 - val_loss: 1.4972 - val_accuracy: 0.4779
# Epoch 33/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9919 - accuracy: 0.7011 - val_loss: 1.2286 - val_accuracy: 0.6096
# Epoch 34/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.9977 - accuracy: 0.7026 - val_loss: 1.2189 - val_accuracy: 0.6026
# Epoch 35/100
# 53/53 [==============================] - 3s 55ms/step - loss: 0.9773 - accuracy: 0.7097 - val_loss: 1.1880 - val_accuracy: 0.5892
# Epoch 36/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9578 - accuracy: 0.7156 - val_loss: 1.1331 - val_accuracy: 0.6334
# Epoch 37/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9769 - accuracy: 0.7050 - val_loss: 1.6742 - val_accuracy: 0.4773
# Epoch 38/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9560 - accuracy: 0.7204 - val_loss: 1.5130 - val_accuracy: 0.5291
# Epoch 39/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9637 - accuracy: 0.7106 - val_loss: 1.2666 - val_accuracy: 0.5874
# Epoch 40/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9441 - accuracy: 0.7222 - val_loss: 1.4153 - val_accuracy: 0.5414
# Epoch 41/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9565 - accuracy: 0.7174 - val_loss: 1.6324 - val_accuracy: 0.4540
# Epoch 42/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9308 - accuracy: 0.7317 - val_loss: 1.3445 - val_accuracy: 0.6113
# Epoch 43/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9426 - accuracy: 0.7290 - val_loss: 1.2377 - val_accuracy: 0.6352
# Epoch 44/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9600 - accuracy: 0.7237 - val_loss: 1.2900 - val_accuracy: 0.6031
# Epoch 45/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9341 - accuracy: 0.7257 - val_loss: 1.2384 - val_accuracy: 0.5868
# Epoch 46/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9260 - accuracy: 0.7329 - val_loss: 1.2713 - val_accuracy: 0.5991
# Epoch 47/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9350 - accuracy: 0.7409 - val_loss: 1.7357 - val_accuracy: 0.4883
# Epoch 48/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.8996 - accuracy: 0.7631 - val_loss: 1.2075 - val_accuracy: 0.6253
# Epoch 49/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9410 - accuracy: 0.7364 - val_loss: 1.4754 - val_accuracy: 0.5612
# Epoch 50/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9214 - accuracy: 0.7412 - val_loss: 1.2936 - val_accuracy: 0.6259
# Epoch 51/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.8980 - accuracy: 0.7572 - val_loss: 2.2983 - val_accuracy: 0.4038
# Epoch 52/100
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9266 - accuracy: 0.7438 - val_loss: 1.2036 - val_accuracy: 0.6265
# Epoch 53/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9276 - accuracy: 0.7415 - val_loss: 1.5874 - val_accuracy: 0.5390
# Epoch 54/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9142 - accuracy: 0.7522 - val_loss: 1.4382 - val_accuracy: 0.5932
# Epoch 55/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9206 - accuracy: 0.7516 - val_loss: 1.5134 - val_accuracy: 0.5565
# Epoch 56/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.8905 - accuracy: 0.7694 - val_loss: 1.2498 - val_accuracy: 0.6265
# Epoch 57/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9174 - accuracy: 0.7503 - val_loss: 1.3093 - val_accuracy: 0.6002
# Epoch 58/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9100 - accuracy: 0.7551 - val_loss: 1.7138 - val_accuracy: 0.5455
# Epoch 59/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.9170 - accuracy: 0.7527 - val_loss: 1.2950 - val_accuracy: 0.6177
# Epoch 60/100
# 53/53 [==============================] - 3s 54ms/step - loss: 0.8952 - accuracy: 0.7655 - val_loss: 1.3945 - val_accuracy: 0.5862
# Epoch 61/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9246 - accuracy: 0.7495 - val_loss: 1.3757 - val_accuracy: 0.5693
# Epoch 62/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.8991 - accuracy: 0.7625 - val_loss: 1.1693 - val_accuracy: 0.6422
# Epoch 63/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9112 - accuracy: 0.7578 - val_loss: 1.2317 - val_accuracy: 0.6515
# Epoch 64/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9285 - accuracy: 0.7605 - val_loss: 1.8379 - val_accuracy: 0.4656
# Epoch 65/100
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9182 - accuracy: 0.7637 - val_loss: 1.2841 - val_accuracy: 0.6195
# Epoch 66/100
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9103 - accuracy: 0.7617 - val_loss: 1.6152 - val_accuracy: 0.5495
# ...
# Epoch 16/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.5983 - accuracy: 0.6085 - val_loss: 2.6554 - val_accuracy: 0.5653
# Epoch 17/50
# 53/53 [==============================] - 3s 58ms/step - loss: 2.5257 - accuracy: 0.6221 - val_loss: 3.0325 - val_accuracy: 0.4825
# Epoch 18/50
# 53/53 [==============================] - 3s 57ms/step - loss: 2.4784 - accuracy: 0.6394 - val_loss: 2.5856 - val_accuracy: 0.5798
# Epoch 19/50
# 53/53 [==============================] - 3s 58ms/step - loss: 2.4281 - accuracy: 0.6444 - val_loss: 2.5684 - val_accuracy: 0.5641
# Epoch 20/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.3533 - accuracy: 0.6655 - val_loss: 2.5251 - val_accuracy: 0.5833
# Epoch 21/50
# 53/53 [==============================] - 3s 59ms/step - loss: 2.3129 - accuracy: 0.6667 - val_loss: 2.7213 - val_accuracy: 0.4703
# Epoch 22/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.2546 - accuracy: 0.6821 - val_loss: 2.6133 - val_accuracy: 0.5478
# Epoch 23/50
# 53/53 [==============================] - 3s 61ms/step - loss: 2.2168 - accuracy: 0.6910 - val_loss: 3.7925 - val_accuracy: 0.3735
# Epoch 24/50
# 53/53 [==============================] - 3s 58ms/step - loss: 2.1783 - accuracy: 0.6937 - val_loss: 2.5602 - val_accuracy: 0.5699
# Epoch 25/50
# 53/53 [==============================] - 3s 59ms/step - loss: 2.1385 - accuracy: 0.6990 - val_loss: 2.2678 - val_accuracy: 0.6334
# Epoch 26/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.0924 - accuracy: 0.7058 - val_loss: 2.3362 - val_accuracy: 0.5967
# Epoch 27/50
# 53/53 [==============================] - 3s 58ms/step - loss: 2.0451 - accuracy: 0.7213 - val_loss: 2.3035 - val_accuracy: 0.5857
# Epoch 28/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.0085 - accuracy: 0.7225 - val_loss: 2.2020 - val_accuracy: 0.6387
# Epoch 29/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.9666 - accuracy: 0.7379 - val_loss: 2.3233 - val_accuracy: 0.6311
# Epoch 30/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.9281 - accuracy: 0.7394 - val_loss: 2.4595 - val_accuracy: 0.5460
# Epoch 31/50
# 53/53 [==============================] - 3s 58ms/step - loss: 1.8883 - accuracy: 0.7465 - val_loss: 2.4267 - val_accuracy: 0.5927
# Epoch 32/50
# 53/53 [==============================] - 3s 57ms/step - loss: 1.8522 - accuracy: 0.7504 - val_loss: 2.4295 - val_accuracy: 0.5880
# Epoch 33/50
# 53/53 [==============================] - 3s 58ms/step - loss: 1.8173 - accuracy: 0.7522 - val_loss: 2.1409 - val_accuracy: 0.6428
# Epoch 34/50
# 53/53 [==============================] - 3s 58ms/step - loss: 1.7894 - accuracy: 0.7617 - val_loss: 2.4120 - val_accuracy: 0.5431
# Epoch 35/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.7940 - accuracy: 0.7409 - val_loss: 2.0762 - val_accuracy: 0.6369
# Epoch 36/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.7158 - accuracy: 0.7774 - val_loss: 2.1429 - val_accuracy: 0.6317
# Epoch 37/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.6893 - accuracy: 0.7732 - val_loss: 2.1219 - val_accuracy: 0.6457
# Epoch 38/50
# 53/53 [==============================] - 3s 57ms/step - loss: 1.6618 - accuracy: 0.7798 - val_loss: 1.9678 - val_accuracy: 0.6643
# Epoch 39/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.6389 - accuracy: 0.7812 - val_loss: 2.1132 - val_accuracy: 0.6195
# Epoch 40/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.6081 - accuracy: 0.7842 - val_loss: 2.1256 - val_accuracy: 0.6259
# Epoch 41/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.5816 - accuracy: 0.7925 - val_loss: 2.0468 - val_accuracy: 0.6247
# Epoch 42/50
# 53/53 [==============================] - 3s 57ms/step - loss: 1.5634 - accuracy: 0.7809 - val_loss: 2.0254 - val_accuracy: 0.6002
# Epoch 43/50
# 53/53 [==============================] - 3s 57ms/step - loss: 1.5456 - accuracy: 0.7869 - val_loss: 2.0321 - val_accuracy: 0.5985
# Epoch 44/50
# 53/53 [==============================] - 3s 58ms/step - loss: 1.5223 - accuracy: 0.7901 - val_loss: 2.0462 - val_accuracy: 0.6136
# Epoch 45/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.4561 - accuracy: 0.8109 - val_loss: 1.9891 - val_accuracy: 0.6410
# Epoch 46/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.4774 - accuracy: 0.7934 - val_loss: 2.4151 - val_accuracy: 0.5204
# Epoch 47/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.4301 - accuracy: 0.8109 - val_loss: 1.9722 - val_accuracy: 0.6305
# Epoch 48/50
# 53/53 [==============================] - 3s 58ms/step - loss: 1.4048 - accuracy: 0.8115 - val_loss: 2.0715 - val_accuracy: 0.6119
# Epoch 49/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.3992 - accuracy: 0.8097 - val_loss: 2.2147 - val_accuracy: 0.6101
# Epoch 50/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.3759 - accuracy: 0.8115 - val_loss: 2.1569 - val_accuracy: 0.5880
# 18/18 [==============================] - 0s 12ms/step - loss: 1.9616 - accuracy: 0.6353
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/50
# 53/53 [==============================] - ETA: 0s - loss: 3.6382 - accuracy: 0.2936WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0092s). Check your callbacks.
# 53/53 [==============================] - 3s 66ms/step - loss: 3.6382 - accuracy: 0.2936 - val_loss: 3.5999 - val_accuracy: 0.3094
# Epoch 2/50
# 53/53 [==============================] - 3s 58ms/step - loss: 3.5288 - accuracy: 0.3773 - val_loss: 3.5267 - val_accuracy: 0.3205
# Epoch 3/50
# 53/53 [==============================] - 3s 59ms/step - loss: 3.4509 - accuracy: 0.3654 - val_loss: 3.4354 - val_accuracy: 0.3537
# Epoch 4/50
# 53/53 [==============================] - 3s 60ms/step - loss: 3.3854 - accuracy: 0.3758 - val_loss: 3.4172 - val_accuracy: 0.3508
# Epoch 5/50
# 53/53 [==============================] - 3s 59ms/step - loss: 3.3294 - accuracy: 0.3823 - val_loss: 3.3293 - val_accuracy: 0.3741
# Epoch 6/50
# 53/53 [==============================] - 3s 60ms/step - loss: 3.2609 - accuracy: 0.3992 - val_loss: 3.3006 - val_accuracy: 0.3724
# Epoch 7/50
# 53/53 [==============================] - 3s 62ms/step - loss: 3.2081 - accuracy: 0.4096 - val_loss: 3.2232 - val_accuracy: 0.3823
# Epoch 8/50
# 53/53 [==============================] - 3s 58ms/step - loss: 3.1515 - accuracy: 0.4405 - val_loss: 3.2348 - val_accuracy: 0.3537
# Epoch 9/50
# 53/53 [==============================] - 3s 60ms/step - loss: 3.0842 - accuracy: 0.4814 - val_loss: 3.1159 - val_accuracy: 0.4097
# Epoch 10/50
# 53/53 [==============================] - 3s 62ms/step - loss: 3.0260 - accuracy: 0.4978 - val_loss: 3.2400 - val_accuracy: 0.3240
# Epoch 11/50
# 53/53 [==============================] - 3s 59ms/step - loss: 2.9503 - accuracy: 0.5194 - val_loss: 2.9900 - val_accuracy: 0.4674
# Epoch 12/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.8743 - accuracy: 0.5390 - val_loss: 2.9079 - val_accuracy: 0.4825
# Epoch 13/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.8039 - accuracy: 0.5637 - val_loss: 2.9807 - val_accuracy: 0.4749
# Epoch 14/50
# 53/53 [==============================] - 3s 58ms/step - loss: 2.7515 - accuracy: 0.5690 - val_loss: 2.8703 - val_accuracy: 0.4977
# Epoch 15/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.6851 - accuracy: 0.5800 - val_loss: 2.8891 - val_accuracy: 0.5087
# Epoch 16/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.6190 - accuracy: 0.5942 - val_loss: 2.9886 - val_accuracy: 0.4749
# Epoch 17/50
# 53/53 [==============================] - 3s 58ms/step - loss: 2.5686 - accuracy: 0.6061 - val_loss: 2.7810 - val_accuracy: 0.5414
# Epoch 18/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.5382 - accuracy: 0.6073 - val_loss: 2.7329 - val_accuracy: 0.4866
# Epoch 19/50
# 53/53 [==============================] - 3s 59ms/step - loss: 2.4712 - accuracy: 0.6239 - val_loss: 3.4591 - val_accuracy: 0.4662
# Epoch 20/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.4291 - accuracy: 0.6308 - val_loss: 2.9119 - val_accuracy: 0.4446
# Epoch 21/50
# 53/53 [==============================] - 3s 59ms/step - loss: 2.3631 - accuracy: 0.6489 - val_loss: 2.7475 - val_accuracy: 0.4452
# Epoch 22/50
# 53/53 [==============================] - 3s 59ms/step - loss: 2.3294 - accuracy: 0.6483 - val_loss: 2.5932 - val_accuracy: 0.5589
# Epoch 23/50
# 53/53 [==============================] - 3s 61ms/step - loss: 2.2878 - accuracy: 0.6589 - val_loss: 2.5413 - val_accuracy: 0.5396
# Epoch 24/50
# 53/53 [==============================] - 3s 62ms/step - loss: 2.1911 - accuracy: 0.6961 - val_loss: 2.7583 - val_accuracy: 0.4843
# Epoch 25/50
# 53/53 [==============================] - 3s 60ms/step - loss: 2.1780 - accuracy: 0.6940 - val_loss: 2.5171 - val_accuracy: 0.5577
# Epoch 26/50
# 53/53 [==============================] - 3s 61ms/step - loss: 2.0931 - accuracy: 0.7044 - val_loss: 2.4870 - val_accuracy: 0.5868
# Epoch 27/50
# 53/53 [==============================] - 3s 61ms/step - loss: 2.0759 - accuracy: 0.7053 - val_loss: 2.3609 - val_accuracy: 0.5944
# Epoch 28/50
# 53/53 [==============================] - 3s 58ms/step - loss: 2.0491 - accuracy: 0.7189 - val_loss: 2.6594 - val_accuracy: 0.5186
# Epoch 29/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.9980 - accuracy: 0.7225 - val_loss: 2.3106 - val_accuracy: 0.5938
# Epoch 30/50
# 53/53 [==============================] - 3s 61ms/step - loss: 1.9752 - accuracy: 0.7168 - val_loss: 2.2912 - val_accuracy: 0.5909
# Epoch 31/50
# 53/53 [==============================] - 3s 58ms/step - loss: 1.9141 - accuracy: 0.7335 - val_loss: 3.2817 - val_accuracy: 0.4738
# Epoch 32/50
# 53/53 [==============================] - 3s 62ms/step - loss: 1.9023 - accuracy: 0.7296 - val_loss: 2.2239 - val_accuracy: 0.5997
# Epoch 33/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.8691 - accuracy: 0.7394 - val_loss: 2.2497 - val_accuracy: 0.5577
# Epoch 34/50
# 53/53 [==============================] - 3s 60ms/step - loss: 1.8165 - accuracy: 0.7513 - val_loss: 2.6209 - val_accuracy: 0.5058
# Epoch 35/50
# 53/53 [==============================] - 3s 59ms/step - loss: 1.7925 - accuracy: 0.7539 - val_loss: 2.4219 - val_accuracy: 0.5676
# Epoch 36/50
#  9/53 [====>.........................] - ETA: 2s - loss: 1.8053 - accuracy: 0.7465
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-43-38d5b303c260> in <module>()
#      17     print(combinations)
#      18     instance  = ModelSelection()
# ---> 19     instance.KFold_GridSearchCV(in_dim,X_train,y_train,X_test, y_test, combinations, grid_result, acc_loss_json)
#
# <ipython-input-42-bac2ae82f4ee> in KFold_GridSearchCV(self, input_dim, X, Y, X_test, y_test, combinations, filename, acc_loss_json)
#      32                 hist = model.fit_generator(generator.flow(X_train, y_train, batch_size=combination[1]), steps_per_epoch=len(X_train) // combination[1], epochs=combination[3],
#      33                                     validation_data=(X_val, y_val),
# ---> 34                                     validation_steps=len(X_val) // combination[1],)
#      35                 loss, acc = model.evaluate(X_test, y_test)
#      36
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, validation_freq, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1827         use_multiprocessing=use_multiprocessing,
#    1828         shuffle=shuffle,
# -> 1829         initial_epoch=initial_epoch)
#    1830
#    1831   @deprecation.deprecated(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:
