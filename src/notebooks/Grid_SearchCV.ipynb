# %% [markdown]
# <a href="https://colab.research.google.com/github/sefeoglu/AE_Parseval_Network/blob/develop/src/notebooks/Grid_SearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import gzip
import pickle
import numpy as np
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import backend as K
from itertools import product
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from wresnet import WideResidualNetwork
import tensorflow
import cv2
import json

# %%
def read_data():
    with open("data.pz", 'rb') as file_:
        with gzip.GzipFile(fileobj=file_) as gzf:
            data = pickle.load(gzf, encoding='latin1', fix_imports=True)
    new_data_X = []
    Y_data = []
    for row in data:
        new_data_X.append(cv2.resize(row['crop'], (32,32)))
        Y_data.append(row['label'])
    new_data_X = np.array(new_data_X)

    return new_data_X, Y_data

# %%
def preprocessing():
    # creating initial dataframe
    X, Y = read_data()
    y_df = pd.DataFrame(Y, columns=['Label'])
    labelencoder = LabelEncoder()
    y_df['Categrory'] = labelencoder.fit_transform(y_df['Label'])


    img_rows, img_cols = X[0].shape


    # transform data set
    if K.image_data_format() == 'channels_first':
        X = X.reshape(X.shape[0], 1, img_rows, img_cols)
        input_shape = (1, img_rows, img_cols)
    else:
        X = X.reshape(X.shape[0], img_rows, img_cols, 1)
        input_shape = (img_rows, img_cols, 1)
    Y_cat = to_categorical(y_df['Categrory'])
    return X, Y_cat

# %%
import tensorflow
from tensorflow.keras.regularizers import l2
from tensorflow.keras import backend as K
from tensorflow.keras.optimizers import SGD

class ModelSelection(object):
    def __init__(self):
        pass
    def KFold_GridSearchCV(self, input_dim, X, Y, X_test, y_test, combinations, filename="log.csv", acc_loss_json="hist.json"):
         # create containers for resulting data
         
        
        res_df = pd.DataFrame(columns=['momentum','learning rate','batch size',
                                      'loss1', 'acc1','loss2', 'acc2','loss3', 'acc3'])
        generator = tensorflow.keras.preprocessing.image.ImageDataGenerator(rotation_range=10,
                               width_shift_range=5./32,
                               height_shift_range=5./32,)
        hist_dict_global = {}

        for i, combination in enumerate(combinations):
            kf = KFold(n_splits=3, random_state=42, shuffle=False)
            metrics_dict = {}
  
            for j, (train_index, test_index) in enumerate(kf.split(X)):
               if i<10:
                X_train, X_val = X[train_index], X[test_index]
                y_train, y_val = Y[train_index], Y[test_index]
                wresnet_ins = WideResidualNetwork(combination[2], combination[0], in_dim,combination[4], nb_classes=4, N=2, k=2, dropout=0.0)
                model = wresnet_ins.create_wide_residual_network()
                opt = tensorflow.keras.optimizers.SGD(learning_rate=combination[0])
                model.compile(loss='categorical_crossentropy', optimizer=opt, metrics= ['accuracy'])
                hist = model.fit_generator(generator.flow(X_train, y_train, batch_size=combination[1]), steps_per_epoch=len(X_train) // combination[1], epochs=combination[3],
                                    validation_data=(X_val, y_val),
                                    validation_steps=len(X_val) // combination[1],)
                loss, acc = model.evaluate(X_test, y_test)

                metrics_dict[j+1] = {"loss": loss, "acc": acc, "epoch_stopped": combination[3]}
                graph_loss_acc = {"val_loss":hist.history["val_loss"], "train_loss":hist.history["loss"], "epoch_stopped": combination[3], 'learning rate': combination[0],
                                     'batch size': combination[1], 'reg_penalty': combination[2]}
                with open(acc_loss_json, 'w', encoding='utf-8') as f:
                  json.dump(graph_loss_acc, f, ensure_ascii=False, indent=4)

            if i <10:
              row = {'momentum': combination[4],'learning rate': combination[0],
                        'batch size': combination[1], 'reg_penalty': combination[2],
                        'epoch_stopped1': metrics_dict[1]["epoch_stopped"], 
                        'loss1': metrics_dict[1]["loss"],'acc1': metrics_dict[1]["acc"],
                        'acc1': metrics_dict[1]["acc"],'epoch_stopped2': metrics_dict[2]["epoch_stopped"],
                        'loss2': metrics_dict[2]["loss"],'acc2': metrics_dict[2]["acc"],
                        'epoch_stopped3': metrics_dict[3]["epoch_stopped"],
                        'loss3': metrics_dict[3]["loss"], 'acc3': metrics_dict[3]["acc"]}
              res_df = res_df.append(row , ignore_index=True)
              res_df.to_csv(filename, sep=";")

# %%
if __name__ == "__main__":
    learning_rate = [0.1, 0.01]
    batch_size = [64,128,256]
    reg_penalty = [0.01, 0.001, 0.0001]
    epochs = [50,100,150]
    momentum = [0.9]
    in_dim = (32,32,1)
    grid_result = "grid_16_9.csv"
    acc_loss_json = "history.json"

    # create list of all different parameter combinations
    param_grid = dict(learning_rate = learning_rate, batch_size = batch_size, 
                      reg_penalty = reg_penalty, epochs = epochs, momentum=momentum)
    combinations = list(product(*param_grid.values()))
    X, Y = preprocessing()
    X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.1, shuffle=False)
    print(combinations)
    instance  = ModelSelection()
    instance.KFold_GridSearchCV(in_dim,X_train,y_train,X_test, y_test, combinations, grid_result, acc_loss_json)
# Out:
# [(0.1, 64, 0.01, 50, 0.9), (0.1, 64, 0.01, 100, 0.9), (0.1, 64, 0.01, 150, 0.9), (0.1, 64, 0.001, 50, 0.9), (0.1, 64, 0.001, 100, 0.9), (0.1, 64, 0.001, 150, 0.9), (0.1, 64, 0.0001, 50, 0.9), (0.1, 64, 0.0001, 100, 0.9), (0.1, 64, 0.0001, 150, 0.9), (0.1, 128, 0.01, 50, 0.9), (0.1, 128, 0.01, 100, 0.9), (0.1, 128, 0.01, 150, 0.9), (0.1, 128, 0.001, 50, 0.9), (0.1, 128, 0.001, 100, 0.9), (0.1, 128, 0.001, 150, 0.9), (0.1, 128, 0.0001, 50, 0.9), (0.1, 128, 0.0001, 100, 0.9), (0.1, 128, 0.0001, 150, 0.9), (0.1, 256, 0.01, 50, 0.9), (0.1, 256, 0.01, 100, 0.9), (0.1, 256, 0.01, 150, 0.9), (0.1, 256, 0.001, 50, 0.9), (0.1, 256, 0.001, 100, 0.9), (0.1, 256, 0.001, 150, 0.9), (0.1, 256, 0.0001, 50, 0.9), (0.1, 256, 0.0001, 100, 0.9), (0.1, 256, 0.0001, 150, 0.9), (0.01, 64, 0.01, 50, 0.9), (0.01, 64, 0.01, 100, 0.9), (0.01, 64, 0.01, 150, 0.9), (0.01, 64, 0.001, 50, 0.9), (0.01, 64, 0.001, 100, 0.9), (0.01, 64, 0.001, 150, 0.9), (0.01, 64, 0.0001, 50, 0.9), (0.01, 64, 0.0001, 100, 0.9), (0.01, 64, 0.0001, 150, 0.9), (0.01, 128, 0.01, 50, 0.9), (0.01, 128, 0.01, 100, 0.9), (0.01, 128, 0.01, 150, 0.9), (0.01, 128, 0.001, 50, 0.9), (0.01, 128, 0.001, 100, 0.9), (0.01, 128, 0.001, 150, 0.9), (0.01, 128, 0.0001, 50, 0.9), (0.01, 128, 0.0001, 100, 0.9), (0.01, 128, 0.0001, 150, 0.9), (0.01, 256, 0.01, 50, 0.9), (0.01, 256, 0.01, 100, 0.9), (0.01, 256, 0.01, 150, 0.9), (0.01, 256, 0.001, 50, 0.9), (0.01, 256, 0.001, 100, 0.9), (0.01, 256, 0.001, 150, 0.9), (0.01, 256, 0.0001, 50, 0.9), (0.01, 256, 0.0001, 100, 0.9), (0.01, 256, 0.0001, 150, 0.9)]
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/50
# 53/53 [==============================] - 3s 61ms/step - loss: 22.0684 - accuracy: 0.2838 - val_loss: 19.8769 - val_accuracy: 0.3687
# Epoch 2/50
# 53/53 [==============================] - 3s 51ms/step - loss: 18.0454 - accuracy: 0.3367 - val_loss: 16.2553 - val_accuracy: 0.3891
# Epoch 3/50
# 53/53 [==============================] - 3s 50ms/step - loss: 14.8355 - accuracy: 0.3456 - val_loss: 13.3688 - val_accuracy: 0.3955
# Epoch 4/50
# 53/53 [==============================] - 3s 50ms/step - loss: 12.2375 - accuracy: 0.3667 - val_loss: 11.0465 - val_accuracy: 0.3780
# Epoch 5/50
# 53/53 [==============================] - 3s 51ms/step - loss: 10.1234 - accuracy: 0.3750 - val_loss: 9.2727 - val_accuracy: 0.3063
# Epoch 6/50
# 53/53 [==============================] - 3s 51ms/step - loss: 8.4196 - accuracy: 0.3842 - val_loss: 7.6681 - val_accuracy: 0.4030
# Epoch 7/50
# 53/53 [==============================] - 3s 51ms/step - loss: 7.0575 - accuracy: 0.3756 - val_loss: 6.5544 - val_accuracy: 0.3133
# Epoch 8/50
# 53/53 [==============================] - 3s 51ms/step - loss: 5.9330 - accuracy: 0.3946 - val_loss: 5.4565 - val_accuracy: 0.4089
# Epoch 9/50
# 53/53 [==============================] - 3s 51ms/step - loss: 5.0323 - accuracy: 0.4068 - val_loss: 4.8363 - val_accuracy: 0.2755
# Epoch 10/50
# 53/53 [==============================] - 3s 50ms/step - loss: 4.3085 - accuracy: 0.4041 - val_loss: 4.0785 - val_accuracy: 0.3774
# Epoch 11/50
# 53/53 [==============================] - 3s 51ms/step - loss: 3.7240 - accuracy: 0.4026 - val_loss: 3.6245 - val_accuracy: 0.3314
# Epoch 12/50
# 53/53 [==============================] - 3s 51ms/step - loss: 3.2495 - accuracy: 0.4183 - val_loss: 3.1999 - val_accuracy: 0.2947
# Epoch 13/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.8510 - accuracy: 0.4341 - val_loss: 2.7888 - val_accuracy: 0.4455
# Epoch 14/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.5337 - accuracy: 0.4673 - val_loss: 2.4458 - val_accuracy: 0.4642
# Epoch 15/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.2578 - accuracy: 0.5048 - val_loss: 2.8355 - val_accuracy: 0.3861
# Epoch 16/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.0404 - accuracy: 0.5039 - val_loss: 2.8125 - val_accuracy: 0.2312
# Epoch 17/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.8661 - accuracy: 0.5285 - val_loss: 1.8286 - val_accuracy: 0.5312
# Epoch 18/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.6977 - accuracy: 0.5531 - val_loss: 1.6617 - val_accuracy: 0.5644
# Epoch 19/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.5745 - accuracy: 0.5674 - val_loss: 1.9783 - val_accuracy: 0.3943
# Epoch 20/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.4901 - accuracy: 0.5704 - val_loss: 2.1900 - val_accuracy: 0.3582
# Epoch 21/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.3910 - accuracy: 0.5867 - val_loss: 1.5708 - val_accuracy: 0.5265
# Epoch 22/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.3195 - accuracy: 0.6063 - val_loss: 1.6480 - val_accuracy: 0.5242
# Epoch 23/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.2524 - accuracy: 0.6324 - val_loss: 1.6898 - val_accuracy: 0.4653
# Epoch 24/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2048 - accuracy: 0.6410 - val_loss: 1.5138 - val_accuracy: 0.5230
# Epoch 25/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2031 - accuracy: 0.6324 - val_loss: 1.6658 - val_accuracy: 0.4613
# Epoch 26/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1287 - accuracy: 0.6594 - val_loss: 1.3017 - val_accuracy: 0.6243
# Epoch 27/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.1252 - accuracy: 0.6526 - val_loss: 1.5386 - val_accuracy: 0.5341
# Epoch 28/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0943 - accuracy: 0.6591 - val_loss: 1.3273 - val_accuracy: 0.5766
# Epoch 29/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0749 - accuracy: 0.6672 - val_loss: 1.3072 - val_accuracy: 0.5702
# Epoch 30/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0889 - accuracy: 0.6639 - val_loss: 1.5399 - val_accuracy: 0.4747
# Epoch 31/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0284 - accuracy: 0.6871 - val_loss: 1.4709 - val_accuracy: 0.5119
# Epoch 32/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0394 - accuracy: 0.6924 - val_loss: 1.3201 - val_accuracy: 0.6226
# Epoch 33/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0220 - accuracy: 0.6784 - val_loss: 1.3470 - val_accuracy: 0.5842
# Epoch 34/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0250 - accuracy: 0.6805 - val_loss: 1.1157 - val_accuracy: 0.6459
# Epoch 35/50
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0168 - accuracy: 0.6951 - val_loss: 1.0545 - val_accuracy: 0.6581
# Epoch 36/50
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0055 - accuracy: 0.6862 - val_loss: 1.1292 - val_accuracy: 0.6733
# Epoch 37/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9982 - accuracy: 0.6909 - val_loss: 1.3279 - val_accuracy: 0.6191
# Epoch 38/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9896 - accuracy: 0.7028 - val_loss: 1.1360 - val_accuracy: 0.6546
# Epoch 39/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9813 - accuracy: 0.7040 - val_loss: 1.5101 - val_accuracy: 0.5655
# Epoch 40/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0098 - accuracy: 0.6906 - val_loss: 1.1827 - val_accuracy: 0.6238
# Epoch 41/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9678 - accuracy: 0.7096 - val_loss: 1.2356 - val_accuracy: 0.6325
# Epoch 42/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9803 - accuracy: 0.7078 - val_loss: 1.1022 - val_accuracy: 0.6540
# Epoch 43/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9805 - accuracy: 0.7081 - val_loss: 1.0791 - val_accuracy: 0.6733
# Epoch 44/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9754 - accuracy: 0.7090 - val_loss: 1.3701 - val_accuracy: 0.5836
# Epoch 45/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9853 - accuracy: 0.7067 - val_loss: 1.1015 - val_accuracy: 0.6698
# Epoch 46/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9562 - accuracy: 0.7233 - val_loss: 1.2561 - val_accuracy: 0.6226
# Epoch 47/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9902 - accuracy: 0.7156 - val_loss: 1.2340 - val_accuracy: 0.6453
# Epoch 48/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9639 - accuracy: 0.7254 - val_loss: 1.4793 - val_accuracy: 0.5492
# Epoch 49/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9624 - accuracy: 0.7239 - val_loss: 1.1886 - val_accuracy: 0.6377
# Epoch 50/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9891 - accuracy: 0.7164 - val_loss: 2.0137 - val_accuracy: 0.4205
# 18/18 [==============================] - 0s 9ms/step - loss: 2.0681 - accuracy: 0.4328
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 21.9261 - accuracy: 0.3307WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0087s). Check your callbacks.
# 53/53 [==============================] - 3s 58ms/step - loss: 21.8849 - accuracy: 0.3333 - val_loss: 19.7332 - val_accuracy: 0.3258
# Epoch 2/50
# 53/53 [==============================] - 3s 51ms/step - loss: 17.8909 - accuracy: 0.3609 - val_loss: 16.1716 - val_accuracy: 0.3666
# Epoch 3/50
# 53/53 [==============================] - 3s 51ms/step - loss: 14.7005 - accuracy: 0.3761 - val_loss: 13.3414 - val_accuracy: 0.3584
# Epoch 4/50
# 53/53 [==============================] - 3s 51ms/step - loss: 12.1106 - accuracy: 0.3865 - val_loss: 11.0231 - val_accuracy: 0.3642
# Epoch 5/50
# 53/53 [==============================] - 3s 50ms/step - loss: 10.0197 - accuracy: 0.3927 - val_loss: 9.1907 - val_accuracy: 0.3450
# Epoch 6/50
# 53/53 [==============================] - 3s 51ms/step - loss: 8.3428 - accuracy: 0.3986 - val_loss: 7.6791 - val_accuracy: 0.3654
# Epoch 7/50
# 53/53 [==============================] - 3s 51ms/step - loss: 6.9688 - accuracy: 0.4049 - val_loss: 6.4776 - val_accuracy: 0.3473
# Epoch 8/50
# 53/53 [==============================] - 3s 52ms/step - loss: 5.8660 - accuracy: 0.3960 - val_loss: 5.4455 - val_accuracy: 0.3776
# Epoch 9/50
# 53/53 [==============================] - 3s 50ms/step - loss: 4.9869 - accuracy: 0.3989 - val_loss: 4.6543 - val_accuracy: 0.3829
# Epoch 10/50
# 53/53 [==============================] - 3s 50ms/step - loss: 4.2577 - accuracy: 0.4173 - val_loss: 4.1177 - val_accuracy: 0.3188
# Epoch 11/50
# 53/53 [==============================] - 3s 50ms/step - loss: 3.6711 - accuracy: 0.4449 - val_loss: 3.4798 - val_accuracy: 0.4505
# Epoch 12/50
# 53/53 [==============================] - 3s 51ms/step - loss: 3.1767 - accuracy: 0.4969 - val_loss: 3.0482 - val_accuracy: 0.4318
# Epoch 13/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.7927 - accuracy: 0.4901 - val_loss: 2.7770 - val_accuracy: 0.3596
# Epoch 14/50
# 53/53 [==============================] - 3s 50ms/step - loss: 2.4533 - accuracy: 0.5191 - val_loss: 2.7575 - val_accuracy: 0.3124
# Epoch 15/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.1908 - accuracy: 0.5387 - val_loss: 3.0594 - val_accuracy: 0.3497
# Epoch 16/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.9702 - accuracy: 0.5536 - val_loss: 2.0008 - val_accuracy: 0.5117
# Epoch 17/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.7993 - accuracy: 0.5577 - val_loss: 1.9206 - val_accuracy: 0.4691
# Epoch 18/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.6574 - accuracy: 0.5619 - val_loss: 1.8582 - val_accuracy: 0.4225
# Epoch 19/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.5315 - accuracy: 0.5868 - val_loss: 1.7097 - val_accuracy: 0.5297
# Epoch 20/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.4273 - accuracy: 0.5934 - val_loss: 1.7030 - val_accuracy: 0.4761
# Epoch 21/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.3475 - accuracy: 0.6112 - val_loss: 1.8069 - val_accuracy: 0.4423
# Epoch 22/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2743 - accuracy: 0.6248 - val_loss: 1.5348 - val_accuracy: 0.4645
# Epoch 23/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2393 - accuracy: 0.6177 - val_loss: 1.9525 - val_accuracy: 0.4330
# Epoch 24/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.1768 - accuracy: 0.6480 - val_loss: 1.5991 - val_accuracy: 0.5035
# Epoch 25/50
# 53/53 [==============================] - 3s 50ms/step - loss: 1.1546 - accuracy: 0.6474 - val_loss: 3.0026 - val_accuracy: 0.3258
# Epoch 26/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.1057 - accuracy: 0.6589 - val_loss: 1.1764 - val_accuracy: 0.6300
# Epoch 27/50
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0799 - accuracy: 0.6708 - val_loss: 1.3978 - val_accuracy: 0.5629
# Epoch 28/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0809 - accuracy: 0.6595 - val_loss: 1.5242 - val_accuracy: 0.4592
# Epoch 29/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0502 - accuracy: 0.6673 - val_loss: 1.2937 - val_accuracy: 0.5420
# Epoch 30/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0213 - accuracy: 0.6759 - val_loss: 1.8032 - val_accuracy: 0.4423
# Epoch 31/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0197 - accuracy: 0.6866 - val_loss: 1.3675 - val_accuracy: 0.5490
# Epoch 32/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9864 - accuracy: 0.6946 - val_loss: 1.2369 - val_accuracy: 0.5886
# Epoch 33/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0232 - accuracy: 0.6866 - val_loss: 1.2025 - val_accuracy: 0.6160
# Epoch 34/50
# 53/53 [==============================] - 3s 50ms/step - loss: 0.9896 - accuracy: 0.7076 - val_loss: 1.2772 - val_accuracy: 0.5501
# Epoch 35/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9772 - accuracy: 0.7067 - val_loss: 1.1651 - val_accuracy: 0.6055
# Epoch 36/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9755 - accuracy: 0.6940 - val_loss: 1.3842 - val_accuracy: 0.5647
# Epoch 37/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9568 - accuracy: 0.7139 - val_loss: 1.3196 - val_accuracy: 0.5775
# Epoch 38/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9753 - accuracy: 0.7067 - val_loss: 1.3037 - val_accuracy: 0.5833
# Epoch 39/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9775 - accuracy: 0.7056 - val_loss: 1.1693 - val_accuracy: 0.6218
# Epoch 40/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9473 - accuracy: 0.7201 - val_loss: 1.2116 - val_accuracy: 0.5921
# Epoch 41/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9968 - accuracy: 0.7044 - val_loss: 1.2666 - val_accuracy: 0.5746
# Epoch 42/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9546 - accuracy: 0.7112 - val_loss: 1.6986 - val_accuracy: 0.4610
# Epoch 43/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9509 - accuracy: 0.7228 - val_loss: 1.3417 - val_accuracy: 0.5752
# Epoch 44/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9548 - accuracy: 0.7145 - val_loss: 1.2077 - val_accuracy: 0.5921
# Epoch 45/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9385 - accuracy: 0.7260 - val_loss: 1.4247 - val_accuracy: 0.5758
# Epoch 46/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9240 - accuracy: 0.7335 - val_loss: 1.2188 - val_accuracy: 0.5892
# Epoch 47/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9443 - accuracy: 0.7245 - val_loss: 1.2762 - val_accuracy: 0.6037
# Epoch 48/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9422 - accuracy: 0.7287 - val_loss: 1.1942 - val_accuracy: 0.6294
# Epoch 49/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9371 - accuracy: 0.7216 - val_loss: 1.2682 - val_accuracy: 0.5997
# Epoch 50/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9343 - accuracy: 0.7278 - val_loss: 1.1184 - val_accuracy: 0.6509
# 18/18 [==============================] - 0s 11ms/step - loss: 0.9687 - accuracy: 0.7016
# conv2:channel:  -1
# Wide Residual Network-16-2 created.
# Epoch 1/50
# 52/53 [============================>.] - ETA: 0s - loss: 21.9164 - accuracy: 0.3419WARNING:tensorflow:Callbacks method `on_test_batch_end` is slow compared to the batch time (batch time: 0.0040s vs `on_test_batch_end` time: 0.0092s). Check your callbacks.
# 53/53 [==============================] - 3s 60ms/step - loss: 21.8758 - accuracy: 0.3422 - val_loss: 19.7372 - val_accuracy: 0.2855
# Epoch 2/50
# 53/53 [==============================] - 3s 52ms/step - loss: 17.9025 - accuracy: 0.3666 - val_loss: 16.1882 - val_accuracy: 0.3228
# Epoch 3/50
# 53/53 [==============================] - 3s 52ms/step - loss: 14.6920 - accuracy: 0.3719 - val_loss: 13.3179 - val_accuracy: 0.3555
# Epoch 4/50
# 53/53 [==============================] - 3s 52ms/step - loss: 12.1093 - accuracy: 0.3820 - val_loss: 11.0129 - val_accuracy: 0.3642
# Epoch 5/50
# 53/53 [==============================] - 3s 52ms/step - loss: 10.0396 - accuracy: 0.3770 - val_loss: 9.1726 - val_accuracy: 0.3409
# Epoch 6/50
# 53/53 [==============================] - 3s 51ms/step - loss: 8.3839 - accuracy: 0.3740 - val_loss: 7.6767 - val_accuracy: 0.3357
# Epoch 7/50
# 53/53 [==============================] - 3s 51ms/step - loss: 7.0047 - accuracy: 0.3862 - val_loss: 6.4343 - val_accuracy: 0.3438
# Epoch 8/50
# 53/53 [==============================] - 3s 51ms/step - loss: 5.9048 - accuracy: 0.3930 - val_loss: 5.5126 - val_accuracy: 0.3100
# Epoch 9/50
# 53/53 [==============================] - 3s 51ms/step - loss: 5.0073 - accuracy: 0.4025 - val_loss: 4.6845 - val_accuracy: 0.3590
# Epoch 10/50
# 53/53 [==============================] - 3s 52ms/step - loss: 4.2846 - accuracy: 0.4173 - val_loss: 4.0115 - val_accuracy: 0.3467
# Epoch 11/50
# 53/53 [==============================] - 3s 51ms/step - loss: 3.7021 - accuracy: 0.4224 - val_loss: 3.4576 - val_accuracy: 0.4056
# Epoch 12/50
# 53/53 [==============================] - 3s 51ms/step - loss: 3.2042 - accuracy: 0.4491 - val_loss: 3.0468 - val_accuracy: 0.4196
# Epoch 13/50
# 53/53 [==============================] - 3s 52ms/step - loss: 2.8230 - accuracy: 0.4717 - val_loss: 2.8629 - val_accuracy: 0.3572
# Epoch 14/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.5069 - accuracy: 0.4847 - val_loss: 2.9467 - val_accuracy: 0.3467
# Epoch 15/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.2391 - accuracy: 0.5055 - val_loss: 2.6033 - val_accuracy: 0.3823
# Epoch 16/50
# 53/53 [==============================] - 3s 51ms/step - loss: 2.0043 - accuracy: 0.5298 - val_loss: 2.1557 - val_accuracy: 0.3543
# Epoch 17/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.8396 - accuracy: 0.5444 - val_loss: 1.9316 - val_accuracy: 0.4417
# Epoch 18/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.6731 - accuracy: 0.5654 - val_loss: 1.7130 - val_accuracy: 0.4994
# Epoch 19/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.5563 - accuracy: 0.5643 - val_loss: 1.7980 - val_accuracy: 0.4336
# Epoch 20/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.4388 - accuracy: 0.5963 - val_loss: 1.6530 - val_accuracy: 0.4674
# Epoch 21/50
# 53/53 [==============================] - 3s 52ms/step - loss: 1.3415 - accuracy: 0.6126 - val_loss: 1.8959 - val_accuracy: 0.4161
# Epoch 22/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.3096 - accuracy: 0.6023 - val_loss: 1.6009 - val_accuracy: 0.4470
# Epoch 23/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.2160 - accuracy: 0.6337 - val_loss: 1.7513 - val_accuracy: 0.4388
# Epoch 24/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.1653 - accuracy: 0.6521 - val_loss: 1.3186 - val_accuracy: 0.5693
# Epoch 25/50
# 53/53 [==============================] - 3s 53ms/step - loss: 1.1295 - accuracy: 0.6592 - val_loss: 1.6920 - val_accuracy: 0.4860
# Epoch 26/50
# 53/53 [==============================] - 3s 52ms/step - loss: 1.1117 - accuracy: 0.6690 - val_loss: 1.3367 - val_accuracy: 0.5530
# Epoch 27/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0685 - accuracy: 0.6771 - val_loss: 1.4129 - val_accuracy: 0.5390
# Epoch 28/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0408 - accuracy: 0.6895 - val_loss: 1.1354 - val_accuracy: 0.6480
# Epoch 29/50
# 53/53 [==============================] - 3s 51ms/step - loss: 1.0298 - accuracy: 0.6791 - val_loss: 1.8246 - val_accuracy: 0.4843
# Epoch 30/50
# 53/53 [==============================] - 3s 52ms/step - loss: 1.0364 - accuracy: 0.6842 - val_loss: 1.2418 - val_accuracy: 0.5962
# Epoch 31/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9992 - accuracy: 0.6928 - val_loss: 1.2409 - val_accuracy: 0.5897
# Epoch 32/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9954 - accuracy: 0.7053 - val_loss: 1.2600 - val_accuracy: 0.5839
# Epoch 33/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9724 - accuracy: 0.7088 - val_loss: 2.0162 - val_accuracy: 0.4586
# Epoch 34/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9558 - accuracy: 0.7112 - val_loss: 1.5482 - val_accuracy: 0.5140
# Epoch 35/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9716 - accuracy: 0.7127 - val_loss: 2.1593 - val_accuracy: 0.3887
# Epoch 36/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9481 - accuracy: 0.7192 - val_loss: 1.5113 - val_accuracy: 0.5058
# Epoch 37/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9468 - accuracy: 0.7228 - val_loss: 1.5831 - val_accuracy: 0.4645
# Epoch 38/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9644 - accuracy: 0.7094 - val_loss: 1.4447 - val_accuracy: 0.5274
# Epoch 39/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9444 - accuracy: 0.7278 - val_loss: 1.4046 - val_accuracy: 0.5198
# Epoch 40/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9361 - accuracy: 0.7207 - val_loss: 1.2557 - val_accuracy: 0.5915
# Epoch 41/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9141 - accuracy: 0.7340 - val_loss: 1.2091 - val_accuracy: 0.6195
# Epoch 42/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9329 - accuracy: 0.7231 - val_loss: 2.1552 - val_accuracy: 0.4505
# Epoch 43/50
# 53/53 [==============================] - 3s 51ms/step - loss: 0.9330 - accuracy: 0.7346 - val_loss: 1.3171 - val_accuracy: 0.5798
# Epoch 44/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9397 - accuracy: 0.7243 - val_loss: 1.1544 - val_accuracy: 0.6538
# Epoch 45/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.8981 - accuracy: 0.7563 - val_loss: 1.2926 - val_accuracy: 0.6026
# Epoch 46/50
# 53/53 [==============================] - 3s 53ms/step - loss: 0.9074 - accuracy: 0.7527 - val_loss: 1.2631 - val_accuracy: 0.6002
# Epoch 47/50
# 53/53 [==============================] - 3s 52ms/step - loss: 0.9305 - accuracy: 0.7403 - val_loss: 1.1937 - val_accuracy: 0.6311
# Epoch 48/50
# 14/53 [======>.......................] - ETA: 1s - loss: 0.8979 - accuracy: 0.7478
